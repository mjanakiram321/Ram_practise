# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install pandas openpyxl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import NearestNeighbors
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
housing_data = pd.read_csv(r"C:\Users\MUSUNURI JANAKIRAM\Desktop\ram\123 AI course\Ram_practise\Ram_practise\California Housing price prediction (All models)\housing1_data.csv")

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
# 4    -122.25     37.85                  52         1627             280
#
#    population  households  median_income  median_house_value  <1H OCEAN  \
# 0         322         126         8.3252              452600          0
# 1        2401        1138         8.3014              358500          0
# 2         496         177         7.2574              352100          0
# 3         558         219         5.6431              341300          0
# 4         565         259         3.8462              342200          0
#
#    INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       0       0         1           0
# ...

# %% [raw]
# # Lasso Regressor : x -> y

# %%
# Separate features and target variable
X = housing_data.drop(columns=['median_house_value'])
y = housing_data['median_house_value']

# %%
# Standardize the data
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Fit Lasso regression model
lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)
# Out:
# C:\Users\MUSUNURI JANAKIRAM\Ram\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.446e+12, tolerance: 2.164e+10
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %%
# Get feature importance (absolute values of coefficients)
feature_importance = np.abs(lasso.coef_)

# %%
# Get the top 3 most important features
important_features = np.argsort(feature_importance)[-3:]

# Print the names of the top 3 most important features
feature_names = X.columns
top_features = feature_names[important_features]

# %%
print("Top 3 most important features:")
for feature in top_features:
    print(feature)
# Out:
# Top 3 most important features:
# longitude
# latitude
# median_income

# %%
# Determine the number of features to remove before R² score begins to drop
r2_scores = []
n_features = len(feature_importance)
for i in range(n_features):
    mask = feature_importance >= np.sort(feature_importance)[i]
    X_train_reduced = X_train[:, mask]
    X_test_reduced = X_test[:, mask]
    lasso_reduced = Lasso(alpha=0.1)
    lasso_reduced.fit(X_train_reduced, y_train)
    y_pred = lasso_reduced.predict(X_test_reduced)
    r2_scores.append(r2_score(y_test, y_pred))
# Out:
# C:\Users\MUSUNURI JANAKIRAM\Ram\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.446e+12, tolerance: 2.164e+10
#   model = cd_fast.enet_coordinate_descent(

# %%
# Find the point where R² score begins to drop
r2_drop_point = np.argmax(np.diff(r2_scores) < 0)
print(f"R² score begins to drop after removing {r2_drop_point} features")
print(r2_scores)
# Out:
# R² score begins to drop after removing 4 features
# [0.6488401007973399, 0.648840216982727, 0.6495717059652091, 0.649657233589211, 0.6496858797479792, 0.6400863125398146, 0.6274114699152511, 0.6252634296664845, 0.6234093238303531, 0.5868756777599782, 0.583224633337956, 0.4789284587486885, 0.47196227390732004]

# %%
# Visualize the R² scores vs number of features removed
plt.figure(figsize=(10, 6))
plt.plot(range(n_features), r2_scores, marker='o')
plt.xlabel("Number of Features Removed")
plt.ylabel("R² Score")
plt.title("R² Score vs Number of Features Removed (Lasso Regression)")
plt.grid(True)
plt.show()

# %% [raw]
# 2. Ridge Regression

# %%
# Fit Ridge regression model
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Get coefficients
ridge_coefficients = ridge.coef_

# %%
# Visualize the R² scores vs number of features removed
plt.figure(figsize=(10, 6))
plt.plot(range(n_features), r2_scores, marker='o')
plt.xlabel("Number of Features Removed")
plt.ylabel("R² Score")
plt.title("R² Score vs Number of Features Removed (Lasso Regression)")
plt.grid(True)
plt.show()

# %%
# Visualize coefficients to confirm that feature selection doesn't take place
plt.figure(figsize=(10, 6))
plt.plot(range(n_features), ridge_coefficients, marker='o', label='Ridge Coefficients')
plt.xlabel("Feature Index")
plt.ylabel("Coefficient Value")
plt.title("Ridge Regression Coefficients")
plt.axhline(0, color='grey', linestyle='--')
plt.legend()
plt.grid(True)
plt.show()
